# %% [markdown]
# mlflow and azure
#
# https://databricks.com/blog/2020/10/13/using-mlops-with-mlflow-and-azure.html
#
# data drfit
#
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-monitor-datasets?tabs=python
#
# # Review the development cycle
# 1. Initial deployment: model trained and selected with existing train&test data
#   * deploy model via mlflow model registry: https://www.mlflow.org/docs/latest/model-registry.html#adding-an-mlflow-model-to-the-model-registry
#
#
# 2. Monitoring model performance on new dataset
#     * supervised learning
#       * creating new test dataset
#       * evaluate on test dataset with current model and log evaluation metrics & params
#       * analyze logged metrics with predefined rules
#       * trigger retrain if failed rules
#     * unsupervised learning
#       * monitoring used param and resulted metrics
#       * analyze logged metrics with predefined rules
#       * trigger retrain if failed rules
#
#
# # Modules
# 1. create new test data - DS notebook, non-generic
#
# 2. train & register in model registry, log test set metrics of registered model
#   * train & test - notebook by DS, non-generic
#   * register - wrapper of <span style="color:blue">mlflow.register_model, client.transition_model_version_stage</span>
#   * logger - wrapper of <span style="color:blue">mlflow.log_metrics, log_params, log_artifact</span>
#     * experiment_id/experiment_name
#     * evaluation metrics
#     * params
#     * evaluation metrics valid range
#   * define rules (what is considered as a good enough model) <span style="color:blue">mlflow.set_tags</span>
#
# 2. use latest model from model registry and make predictions in on new test data, wrapper of <span style="color:blue">client = mlflow.tracking.MlflowClient()
# latest_model = client.get_latest_versions(name = model_name, stages=[stage])</span>
# 3. analyze logged metrics with predefined rules - wrapper of <span style="color:blue">mlflow.search_runs</span>
#   * input
#     * experiment_id/experiment_name
#   * output: retrain, /path/to/notebook
# 4. trigger retrain if failed rules
#   * trigger azure data factory pipeline for DS training notebook (via storage event or custom event) or
#   * execute the DS notebook by calling <span style="color:blue">%run /Users/path/to/notebookA</span>
#
# 5. move to production if meet rules:
#
# # Model Stages
# None: WIP, Staging: Ready to test, Production: Serving, Archive: expired Staging and Production model
#
# https://docs.databricks.com/_static/notebooks/mlflow/mlflow-model-registry-example.html

# %%
#%pip install mlflow
#%pip install pymysql

# %%
import mlflow
from mlflow.tracking.client import MlflowClient
client = MlflowClient()
client.list_experiments()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[85]: [&lt;Experiment: artifact_location=&#39;dbfs:/databricks/mlflow-tracking/2198935684228346&#39;, experiment_id=&#39;2198935684228346&#39;, lifecycle_stage=&#39;active&#39;, name=&#39;/Users/saurabh.verma2@adidas.com/test_experiment&#39;, tags={&#39;mlflow.experimentType&#39;: &#39;MLFLOW_EXPERIMENT&#39;,
#   &#39;mlflow.ownerEmail&#39;: &#39;saurabh.verma2@adidas.com&#39;,
#   &#39;mlflow.ownerId&#39;: &#39;7278444638023685&#39;}&gt;,
#  &lt;Experiment: artifact_location=&#39;dbfs:/databricks/mlflow-tracking/3790025709814458&#39;, experiment_id=&#39;3790025709814458&#39;, lifecycle_stage=&#39;active&#39;, name=&#39;/Users/saurabh.verma2@adidas.com/Feature Store Taxi example notebook&#39;, tags={&#39;mlflow.experimentType&#39;: &#39;NOTEBOOK&#39;,
#   &#39;mlflow.ownerEmail&#39;: &#39;saurabh.verma2@adidas.com&#39;,
#   &#39;mlflow.ownerId&#39;: &#39;7278444638023685&#39;}&gt;,
#  &lt;Experiment: artifact_location=&#39;dbfs:/databricks/mlflow-tracking/3856218966757814&#39;, experiment_id=&#39;3856218966757814&#39;, lifecycle_stage=&#39;active&#39;, name=&#39;/Users/saurabh.verma2@adidas.com/ml-test&#39;, tags={&#39;mlflow.experimentType&#39;: &#39;NOTEBOOK&#39;,
#   &#39;mlflow.ownerEmail&#39;: &#39;saurabh.verma2@adidas.com&#39;,
#   &#39;mlflow.ownerId&#39;: &#39;7278444638023685&#39;}&gt;]</div>

# %%
experiment = mlflow.get_experiment_by_name("/Users/saurabh.verma2@adidas.com/test_experiment")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
experiment
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[80]: &lt;Experiment: artifact_location=&#39;dbfs:/databricks/mlflow-tracking/2198935684228346&#39;, experiment_id=&#39;2198935684228346&#39;, lifecycle_stage=&#39;active&#39;, name=&#39;/Users/saurabh.verma2@adidas.com/test_experiment&#39;, tags={&#39;mlflow.experimentType&#39;: &#39;MLFLOW_EXPERIMENT&#39;,
#  &#39;mlflow.ownerEmail&#39;: &#39;saurabh.verma2@adidas.com&#39;,
#  &#39;mlflow.ownerId&#39;: &#39;7278444638023685&#39;}&gt;</div>

# %% [markdown]
# # Generate Demo Model

# %%
from sklearn.datasets import load_iris
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)


import mlflow
import mlflow.sklearn
mlflow.sklearn.autolog()
#mlflow.set_tracking_uri("databricks") #
#mlflow.set_registry_uri("mysql+pymysql://mlflow-user:password@localhost:3306/mlflowruns")
# Note: on Databricks, the experiment name passed to set_experiment must be a valid path
# in the workspace, like '/Users/<your-username>/my-experiment'. See
# https://docs.databricks.com/user-guide/workspace.html for more info.
# mlflow.set_experiment("/my-experiment")
mlflow.set_experiment(experiment_name = experiment.name)

#NOTEBOOK_ID = 1557754033372830

KEY_EVALUATION = "eval_metric"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data = spark.read.option("header",True).option("inferSchema",True).csv('/FileStore/tables/Iris.csv')
data = data.drop("id")
raw_data = data.drop_duplicates()
display(raw_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SepalLengthCm</th><th>SepalWidthCm</th><th>PetalLengthCm</th><th>PetalWidthCm</th><th>Species</th></tr></thead><tbody><tr><td>5.0</td><td>2.0</td><td>3.5</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>6.8</td><td>3.0</td><td>5.5</td><td>2.1</td><td>Iris-virginica</td></tr><tr><td>6.7</td><td>3.0</td><td>5.2</td><td>2.3</td><td>Iris-virginica</td></tr><tr><td>5.6</td><td>2.9</td><td>3.6</td><td>1.3</td><td>Iris-versicolor</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>6.5</td><td>3.2</td><td>5.1</td><td>2.0</td><td>Iris-virginica</td></tr><tr><td>5.4</td><td>3.7</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>5.0</td><td>3.2</td><td>1.2</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>6.0</td><td>2.9</td><td>4.5</td><td>1.5</td><td>Iris-versicolor</td></tr><tr><td>5.0</td><td>3.6</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>4.4</td><td>3.2</td><td>1.3</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>6.4</td><td>2.7</td><td>5.3</td><td>1.9</td><td>Iris-virginica</td></tr><tr><td>6.3</td><td>2.8</td><td>5.1</td><td>1.5</td><td>Iris-virginica</td></tr><tr><td>6.4</td><td>2.9</td><td>4.3</td><td>1.3</td><td>Iris-versicolor</td></tr><tr><td>5.0</td><td>3.4</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>5.6</td><td>2.5</td><td>3.9</td><td>1.1</td><td>Iris-versicolor</td></tr><tr><td>7.6</td><td>3.0</td><td>6.6</td><td>2.1</td><td>Iris-virginica</td></tr><tr><td>6.9</td><td>3.1</td><td>5.4</td><td>2.1</td><td>Iris-virginica</td></tr><tr><td>5.8</td><td>2.7</td><td>3.9</td><td>1.2</td><td>Iris-versicolor</td></tr><tr><td>5.6</td><td>2.7</td><td>4.2</td><td>1.3</td><td>Iris-versicolor</td></tr><tr><td>5.2</td><td>3.4</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>5.5</td><td>2.4</td><td>3.7</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>6.0</td><td>3.4</td><td>4.5</td><td>1.6</td><td>Iris-versicolor</td></tr><tr><td>7.7</td><td>3.8</td><td>6.7</td><td>2.2</td><td>Iris-virginica</td></tr><tr><td>6.2</td><td>3.4</td><td>5.4</td><td>2.3</td><td>Iris-virginica</td></tr><tr><td>6.6</td><td>3.0</td><td>4.4</td><td>1.4</td><td>Iris-versicolor</td></tr><tr><td>6.5</td><td>3.0</td><td>5.8</td><td>2.2</td><td>Iris-virginica</td></tr><tr><td>6.4</td><td>2.8</td><td>5.6</td><td>2.1</td><td>Iris-virginica</td></tr><tr><td>6.7</td><td>3.3</td><td>5.7</td><td>2.5</td><td>Iris-virginica</td></tr><tr><td>5.5</td><td>2.4</td><td>3.8</td><td>1.1</td><td>Iris-versicolor</td></tr><tr><td>5.0</td><td>3.0</td><td>1.6</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.1</td><td>Iris-setosa</td></tr><tr><td>5.1</td><td>3.4</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>4.8</td><td>3.1</td><td>1.6</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>7.0</td><td>3.2</td><td>4.7</td><td>1.4</td><td>Iris-versicolor</td></tr><tr><td>5.8</td><td>2.7</td><td>4.1</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>5.4</td><td>3.9</td><td>1.3</td><td>0.4</td><td>Iris-setosa</td></tr><tr><td>6.3</td><td>2.5</td><td>5.0</td><td>1.9</td><td>Iris-virginica</td></tr><tr><td>4.8</td><td>3.0</td><td>1.4</td><td>0.1</td><td>Iris-setosa</td></tr><tr><td>6.9</td><td>3.1</td><td>4.9</td><td>1.5</td><td>Iris-versicolor</td></tr><tr><td>6.3</td><td>2.3</td><td>4.4</td><td>1.3</td><td>Iris-versicolor</td></tr><tr><td>6.2</td><td>2.2</td><td>4.5</td><td>1.5</td><td>Iris-versicolor</td></tr><tr><td>5.0</td><td>2.3</td><td>3.3</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>6.1</td><td>3.0</td><td>4.9</td><td>1.8</td><td>Iris-virginica</td></tr><tr><td>4.9</td><td>2.4</td><td>3.3</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>6.0</td><td>2.2</td><td>4.0</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>7.9</td><td>3.8</td><td>6.4</td><td>2.0</td><td>Iris-virginica</td></tr><tr><td>6.5</td><td>3.0 ...

# %%
# raw_data.createOrReplaceTempView("iris_dataset")
# raw_data.write.format("delta").saveAsTable("iris_features_example.test_table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql 
# CREATE DATABASE IF NOT EXISTS iris_features_example;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# from databricks import feature_store
# from pyspark.sql.functions import *
# from pyspark.sql.types import FloatType, IntegerType, StringType
# fs = feature_store.FeatureStoreClient()
# fs.create_feature_table(
#     name= "iris_features_example.iris_features",
#     keys=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"],
#     features_df=raw_data,
# #     partition_columns="yyyy_mm",
#     description="isis dataset features",
# )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# delta = spark.read.format("delta").table("iris_features_example.iris_features").drop("test")
# delta.write.format("delta").mode("OVERWRITE").option("overwriteSchema", True).saveAsTable("iris_features_example.iris_features")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# test2 = fs.read_table(
#   name='iris_features_example.iris_features',
# #   as_of_delta_timestamp = str('2021-08-18 12:21:19')
# )
# display(test2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SepalLengthCm</th><th>SepalWidthCm</th><th>PetalLengthCm</th><th>PetalWidthCm</th><th>Species</th><th>test</th></tr></thead><tbody><tr><td>5.0</td><td>2.0</td><td>3.5</td><td>1.0</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>6.8</td><td>3.0</td><td>5.5</td><td>2.1</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>6.7</td><td>3.0</td><td>5.2</td><td>2.3</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>5.6</td><td>2.9</td><td>3.6</td><td>1.3</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>6.5</td><td>3.2</td><td>5.1</td><td>2.0</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>5.4</td><td>3.7</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.0</td><td>3.2</td><td>1.2</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>6.0</td><td>2.9</td><td>4.5</td><td>1.5</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.0</td><td>3.6</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.4</td><td>3.2</td><td>1.3</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>6.4</td><td>2.7</td><td>5.3</td><td>1.9</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>6.3</td><td>2.8</td><td>5.1</td><td>1.5</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>6.4</td><td>2.9</td><td>4.3</td><td>1.3</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.0</td><td>3.4</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.6</td><td>2.5</td><td>3.9</td><td>1.1</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>7.6</td><td>3.0</td><td>6.6</td><td>2.1</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>6.9</td><td>3.1</td><td>5.4</td><td>2.1</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>5.8</td><td>2.7</td><td>3.9</td><td>1.2</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.6</td><td>2.7</td><td>4.2</td><td>1.3</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.2</td><td>3.4</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.5</td><td>2.4</td><td>3.7</td><td>1.0</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>6.0</td><td>3.4</td><td>4.5</td><td>1.6</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>7.7</td><td>3.8</td><td>6.7</td><td>2.2</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>6.2</td><td>3.4</td><td>5.4</td><td>2.3</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>6.6</td><td>3.0</td><td>4.4</td><td>1.4</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>6.5</td><td>3.0</td><td>5.8</td><td>2.2</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>6.4</td><td>2.8</td><td>5.6</td><td>2.1</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>6.7</td><td>3.3</td><td>5.7</td><td>2.5</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>5.5</td><td>2.4</td><td>3.8</td><td>1.1</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.0</td><td>3.0</td><td>1.6</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.1</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.1</td><td>3.4</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.8</td><td>3.1</td><td>1.6</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>7.0</td><td>3.2</td><td>4.7</td><td>1.4</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.8</td><td>2.7</td><td>4.1</td><td>1.0</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.4</td><td>3.9</td><td>1.3</td><td>0.4</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>6.3</td><td>2.5</td><td>5.0</td><td>1.9</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>4.8</td><td>3.0</td><td>1.4</td><td>0.1</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>6.9</td><td>3.1</td><td>4.9</td><td>1.5</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>6.3</td><td>2.3</td><td>4.4</td><td>1.3</td><td>Iris-versicolor</td><td>abc</td></tr><t ...

# %%
# raw_data_2 = raw_data.withColumn("test", lit("abc"))
# raw_data_2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[63]: DataFrame[SepalLengthCm: double, SepalWidthCm: double, PetalLengthCm: double, PetalWidthCm: double, Species: string, test: string]</div>

# %%
# fs.write_table(
#   name='iris_features_example.iris_features',
#   df=raw_data_2,
#   mode="merge",
# )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021/08/21 17:10:06 INFO databricks.feature_store.utils.spark_listener: Actively listening to data sources.
# </div>

# %%
# %sql
# -- ALTER TABLE iris_features_example.iris_features ADD COLUMNS (test string)
# -- -- DESCRIBE HISTORY iris_features_example.iris_features
# select * from iris_features_example.iris_features
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SepalLengthCm</th><th>SepalWidthCm</th><th>PetalLengthCm</th><th>PetalWidthCm</th><th>Species</th><th>test</th></tr></thead><tbody><tr><td>4.3</td><td>3.0</td><td>1.1</td><td>0.1</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.4</td><td>2.9</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.4</td><td>3.0</td><td>1.3</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.4</td><td>3.2</td><td>1.3</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.5</td><td>2.3</td><td>1.3</td><td>0.3</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.6</td><td>3.2</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.6</td><td>3.4</td><td>1.4</td><td>0.3</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.6</td><td>3.6</td><td>1.0</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.7</td><td>3.2</td><td>1.3</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.7</td><td>3.2</td><td>1.6</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.8</td><td>3.0</td><td>1.4</td><td>0.1</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.8</td><td>3.0</td><td>1.4</td><td>0.3</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.8</td><td>3.1</td><td>1.6</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.8</td><td>3.4</td><td>1.6</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.8</td><td>3.4</td><td>1.9</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.9</td><td>2.4</td><td>3.3</td><td>1.0</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>4.9</td><td>2.5</td><td>4.5</td><td>1.7</td><td>Iris-virginica</td><td>abc</td></tr><tr><td>4.9</td><td>3.0</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.1</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.0</td><td>2.0</td><td>3.5</td><td>1.0</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.0</td><td>2.3</td><td>3.3</td><td>1.0</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.0</td><td>3.0</td><td>1.6</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.0</td><td>3.2</td><td>1.2</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.0</td><td>3.3</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.0</td><td>3.4</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.0</td><td>3.4</td><td>1.6</td><td>0.4</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.0</td><td>3.5</td><td>1.3</td><td>0.3</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.0</td><td>3.5</td><td>1.6</td><td>0.6</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.0</td><td>3.6</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.1</td><td>2.5</td><td>3.0</td><td>1.1</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.1</td><td>3.3</td><td>1.7</td><td>0.5</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.1</td><td>3.4</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.3</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.1</td><td>3.7</td><td>1.5</td><td>0.4</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.1</td><td>3.8</td><td>1.5</td><td>0.3</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.1</td><td>3.8</td><td>1.6</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.1</td><td>3.8</td><td>1.9</td><td>0.4</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.2</td><td>2.7</td><td>3.9</td><td>1.4</td><td>Iris-versicolor</td><td>abc</td></tr><tr><td>5.2</td><td>3.4</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td><td>abc</td></tr><tr><td>5.2</td><td>3.5</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td><td>ab ...

# %%
# from databricks.feature_store import FeatureLookup
# iris_feature_lookups = [
#     FeatureLookup( 
#       table_name = 'iris_features_example.iris_features',
#       feature_name = "test",
#       lookup_key = ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"],
#     )
# ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# training_set = fs.create_training_set(
#   raw_data,
#   feature_lookups = iris_feature_lookups,
#   label = "Species",
# #   exclude_columns = exclude_columns
# )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training_df = training_set.load_df()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# from sklearn.model_selection import train_test_split
# from mlflow.tracking import MlflowClient
# import lightgbm as lgb
# import mlflow.lightgbm
# from mlflow.models.signature import infer_signature

# features_and_label = training_df.columns

# # Collect data into a Pandas array for training
# data = training_df.toPandas()[features_and_label]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data = raw_data.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def load_iris_data(data):
#     data = load_iris()
#     X = data.data
#     y = data.target
    X = data.drop(["Species"], axis=1)
    y = data["Species"]
    
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 10)
    input_data = (X_train, X_test, y_train, y_test)
      
    return input_data

def train_predict_evaluate_dtree(input_data, params):
    with mlflow.start_run(run_name = "Decision Tree Classifier Experiments"):
        mlflow.sklearn.autolog()
        X_train, X_test, y_train, y_test = input_data
        clf = DecisionTreeClassifier(random_state=42, max_leaf_nodes=params['leaf_nodes'], max_depth=params['max_depth'])
        clf.fit(X_train, y_train)

        y_pred = clf.predict(X_test)
        test_accuracy = metrics.accuracy_score(y_test, y_pred)
        test_f1_score = metrics.f1_score(y_test, y_pred, average='weighted')
        test_metrics = (test_accuracy, test_f1_score)
        
        signature = infer_signature(X_train, clf.predict(X_test))
        mlflow.log_metric('test_accuracy' , test_accuracy)
        mlflow.log_metric('test_f1_score', test_f1_score)
#         mlflow.sklearn.log_model(clf, "iris_decision_tree", signature=signature)
    return clf, clf_trained, test_metrics
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# input_data = load_iris_data()
mlflow.end_run()
input_data = load_iris_data(data)
params = {'leaf_nodes': 4, 'max_depth' :4}
iris_model, test_metrics = train_predict_evaluate_dtree(input_data, params)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3856218966757820&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> input_data <span class="ansi-blue-fg">=</span> load_iris_data<span class="ansi-blue-fg">(</span>data<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> params <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">{</span><span class="ansi-blue-fg">&#39;leaf_nodes&#39;</span><span class="ansi-blue-fg">:</span> <span class="ansi-cyan-fg">4</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;max_depth&#39;</span> <span class="ansi-blue-fg">:</span><span class="ansi-cyan-fg">4</span><span class="ansi-blue-fg">}</span>
# <span class="ansi-green-fg">----&gt; 5</span><span class="ansi-red-fg"> </span>iris_model<span class="ansi-blue-fg">,</span> test_metrics <span class="ansi-blue-fg">=</span> train_predict_evaluate_dtree<span class="ansi-blue-fg">(</span>input_data<span class="ansi-blue-fg">,</span> params<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">&lt;command-3856218966757819&gt;</span> in <span class="ansi-cyan-fg">train_predict_evaluate_dtree</span><span class="ansi-blue-fg">(input_data, params)</span>
# <span class="ansi-green-intense-fg ansi-bold">     15</span>         mlflow<span class="ansi-blue-fg">.</span>sklearn<span class="ansi-blue-fg">.</span>autolog<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     16</span>         X_train<span class="ansi-blue-fg">,</span> X_test<span class="ansi-blue-fg">,</span> y_train<span class="ansi-blue-fg">,</span> y_test <span class="ansi-blue-fg">=</span> input_data
# <span class="ansi-green-fg">---&gt; 17</span><span class="ansi-red-fg">         </span>clf <span class="ansi-blue-fg">=</span> DecisionTreeClassifier<span class="ansi-blue-fg">(</span>random_state<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">42</span><span class="ansi-blue-fg">,</span> max_leaf_nodes<span class="ansi-blue-fg">=</span>params<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;leaf_nodes&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> max_depth<span class="ansi-blue-fg">=</span>params<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;max_depth&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     18</span>         clf<span class="ansi-blue-fg">.</span>fit<span class="ansi-blue-fg">(</span>X_train<span class="ansi-blue-fg">,</span> y_train<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     19</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;DecisionTreeClassifier&#39; is not defined</div>

# %%
# fs.log_model(
#   iris_model,
#   artifact_path="iris_decision_tree_model_packaged",
#   flavor=mlflow.sklearn,
#   training_set=training_set,
#   registered_model_name="iris_decision_tree_model"
# )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ValueError</span>                                Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-878965470131372&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> fs.log_model(
# </span><span class="ansi-green-intense-fg ansi-bold">      2</span>   iris_model_trained<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>   artifact_path<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#34;iris_decision_tree_model_packaged&#34;</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>   flavor<span class="ansi-blue-fg">=</span>mlflow<span class="ansi-blue-fg">.</span>sklearn<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>   training_set<span class="ansi-blue-fg">=</span>training_set<span class="ansi-blue-fg">,</span>
#
# <span class="ansi-green-fg">/databricks/.python_edge_libs/databricks/feature_store/client.py</span> in <span class="ansi-cyan-fg">log_model</span><span class="ansi-blue-fg">(self, model, artifact_path, flavor, training_set, registered_model_name, await_registration_for, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1259</span>                 )
# <span class="ansi-green-intense-fg ansi-bold">   1260</span>             <span class="ansi-green-fg">if</span> <span class="ansi-green-fg">not</span> <span class="ansi-blue-fg">&#34;python_function&#34;</span> <span class="ansi-green-fg">in</span> raw_mlflow_model<span class="ansi-blue-fg">.</span>flavors<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 1261</span><span class="ansi-red-fg">                 raise ValueError(
# </span><span class="ansi-green-intense-fg ansi-bold">   1262</span>                     <span class="ansi-blue-fg">f&#34;FeatureStoreClient.log_model does not support &#39;{flavor.__name__}&#39; &#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">   1263</span>                     <span class="ansi-blue-fg">f&#34;since it does not have a python_function model flavor.&#34;</span>
#
# <span class="ansi-red-fg">ValueError</span>: FeatureStoreClient.log_model does not support &#39;mlflow.sklearn&#39; since it does not have a python_function model flavor.</div>

# %%
stg_model_version = get_lastest_model(model_name = 'iris_decision_tree_model', stage = 'Staging')  #Staging
stg_model_version
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: &lt;ModelVersion: creation_timestamp=1629798715287, current_stage=&#39;Staging&#39;, description=&#39;&#39;, last_updated_timestamp=1629798927163, name=&#39;iris_decision_tree_model&#39;, run_id=&#39;e9c5060d17814ff78de664457a5c76ce&#39;, run_link=&#39;&#39;, source=&#39;dbfs:/databricks/mlflow-tracking/2198935684228346/e9c5060d17814ff78de664457a5c76ce/artifacts/iris_decision_tree&#39;, status=&#39;READY&#39;, status_message=&#39;&#39;, tags={}, user_id=&#39;saurabh.verma2@adidas.com&#39;, version=&#39;4&#39;&gt;</div>

# %%
# input_data = load_iris_data(data)
# X_train, X_test, y_train, y_test = input_data
model_name = 'iris_decision_tree_model'
model = mlflow.pyfunc.load_model(f"models:/{model_name}/Staging")

# Sanity-check: This should match the predictions logged by MLflow
print(f'pred: {model.predict(X_test)}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">pred: [&#39;Iris-setosa&#39; &#39;Iris-virginica&#39; &#39;Iris-setosa&#39; &#39;Iris-virginica&#39;
#  &#39;Iris-setosa&#39; &#39;Iris-virginica&#39; &#39;Iris-setosa&#39; &#39;Iris-virginica&#39;
#  &#39;Iris-versicolor&#39; &#39;Iris-virginica&#39; &#39;Iris-versicolor&#39; &#39;Iris-versicolor&#39;
#  &#39;Iris-setosa&#39; &#39;Iris-versicolor&#39; &#39;Iris-virginica&#39; &#39;Iris-versicolor&#39;
#  &#39;Iris-versicolor&#39; &#39;Iris-setosa&#39; &#39;Iris-versicolor&#39; &#39;Iris-virginica&#39;
#  &#39;Iris-setosa&#39; &#39;Iris-virginica&#39; &#39;Iris-versicolor&#39; &#39;Iris-virginica&#39;
#  &#39;Iris-virginica&#39; &#39;Iris-setosa&#39; &#39;Iris-setosa&#39; &#39;Iris-versicolor&#39;
#  &#39;Iris-versicolor&#39; &#39;Iris-setosa&#39; &#39;Iris-versicolor&#39; &#39;Iris-setosa&#39;
#  &#39;Iris-virginica&#39; &#39;Iris-versicolor&#39; &#39;Iris-versicolor&#39; &#39;Iris-setosa&#39;
#  &#39;Iris-virginica&#39;]
# </div>

# %%
from pyspark.sql.functions import struct
from pyspark.sql.types import *

spark_df = spark.createDataFrame(X_train)
apply_model_udf = mlflow.pyfunc.spark_udf(spark, f"models:/{model_name}/Production", result_type=StringType())


# Apply the model to the new data
udf_inputs = struct(*(X_train.columns.tolist()))


new_data = spark_df.withColumn(
  "prediction",
  apply_model_udf(udf_inputs)
#   apply_model_udf(struct(*('SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm')))
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(new_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SepalLengthCm</th><th>SepalWidthCm</th><th>PetalLengthCm</th><th>PetalWidthCm</th><th>prediction</th></tr></thead><tbody><tr><td>5.2</td><td>3.5</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>6.5</td><td>3.0</td><td>5.8</td><td>2.2</td><td>Iris-virginica</td></tr><tr><td>4.7</td><td>3.2</td><td>1.3</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>6.0</td><td>2.2</td><td>5.0</td><td>1.5</td><td>Iris-versicolor</td></tr><tr><td>5.1</td><td>3.4</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>5.5</td><td>3.5</td><td>1.3</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>6.8</td><td>3.2</td><td>5.9</td><td>2.3</td><td>Iris-virginica</td></tr><tr><td>7.4</td><td>2.8</td><td>6.1</td><td>1.9</td><td>Iris-virginica</td></tr><tr><td>5.8</td><td>4.0</td><td>1.2</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>4.9</td><td>3.0</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>5.0</td><td>3.4</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>7.7</td><td>3.0</td><td>6.1</td><td>2.3</td><td>Iris-virginica</td></tr><tr><td>5.2</td><td>3.4</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>5.0</td><td>3.4</td><td>1.6</td><td>0.4</td><td>Iris-setosa</td></tr><tr><td>5.5</td><td>2.4</td><td>3.8</td><td>1.1</td><td>Iris-versicolor</td></tr><tr><td>5.6</td><td>2.9</td><td>3.6</td><td>1.3</td><td>Iris-versicolor</td></tr><tr><td>6.7</td><td>3.0</td><td>5.0</td><td>1.7</td><td>Iris-versicolor</td></tr><tr><td>6.5</td><td>3.0</td><td>5.2</td><td>2.0</td><td>Iris-virginica</td></tr><tr><td>4.5</td><td>2.3</td><td>1.3</td><td>0.3</td><td>Iris-setosa</td></tr><tr><td>6.3</td><td>2.5</td><td>5.0</td><td>1.9</td><td>Iris-virginica</td></tr><tr><td>6.1</td><td>2.6</td><td>5.6</td><td>1.4</td><td>Iris-versicolor</td></tr><tr><td>5.1</td><td>3.8</td><td>1.9</td><td>0.4</td><td>Iris-setosa</td></tr><tr><td>5.9</td><td>3.2</td><td>4.8</td><td>1.8</td><td>Iris-virginica</td></tr><tr><td>6.0</td><td>2.2</td><td>4.0</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>4.4</td><td>3.0</td><td>1.3</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>5.7</td><td>2.6</td><td>3.5</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>6.1</td><td>3.0</td><td>4.9</td><td>1.8</td><td>Iris-virginica</td></tr><tr><td>5.8</td><td>2.7</td><td>5.1</td><td>1.9</td><td>Iris-virginica</td></tr><tr><td>5.0</td><td>2.3</td><td>3.3</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>5.4</td><td>3.4</td><td>1.5</td><td>0.4</td><td>Iris-setosa</td></tr><tr><td>5.7</td><td>2.5</td><td>5.0</td><td>2.0</td><td>Iris-virginica</td></tr><tr><td>5.9</td><td>3.0</td><td>5.1</td><td>1.8</td><td>Iris-virginica</td></tr><tr><td>6.1</td><td>3.0</td><td>4.6</td><td>1.4</td><td>Iris-versicolor</td></tr><tr><td>6.3</td><td>3.3</td><td>4.7</td><td>1.6</td><td>Iris-versicolor</td></tr><tr><td>5.4</td><td>3.7</td><td>1.5</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>6.7</td><td>3.3</td><td>5.7</td><td>2.1</td><td>Iris-virginica</td></tr><tr><td>4.4</td><td>2.9</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>7.0</td><td>3.2</td><td>4.7</td><td>1.4</td><td>Iris-versicolor</td></tr><tr><td>4.8</td><td>3.4</td><td>1.9</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>5.7</td><td>4.4</td><td>1.5</td><td>0.4</td><td>Iris-setosa</td></tr><tr><td>4.6</td><td>3.4</td><td>1.4</td><td>0.3</td><td>Iris-setosa</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td><td>Iris-setosa</td></tr><tr><td>6.5</td><td>3.2</td><td>5.1</td><td>2.0</td><td>Iris-virginica</td></tr><tr><td>4.9</td><td>2.4</td><td>3.3</td><td>1.0</td><td>Iris-versicolor</td></tr><tr><td>7.1</td><td>3.0</td><td>5.9</td><td>2.1</td><td>Iris-virginica</td></tr><tr><td>5.1</td><td>3.3</td><td>1.7</td><td>0.5</td><td>Iris-setosa</td></tr><tr><td>5.4</td><td>3.0</td><td>4.5</td><td>1.5</td><td>Iris-versicolor</td></tr><tr><td>5.0</td><td>3.2</td><td>1.2</td><td>0.2 ...

# %% [markdown]
# # Model Serving

# %%
# import os
# os.environ["DATABRICKS_TOKEN"] = "<YOUR_TOKEN>"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# # Replace with code snippet from the model serving page
# import os
# import requests
# import pandas as pd

# def score_model(dataset):
#   url = 'https://dbc-af318caa-90f9.cloud.databricks.com/model/iris_decision_tree_model/Production/invocations'
#   headers = {'Authorization': f'Bearer {os.environ.get("DATABRICKS_TOKEN")}'}
#   data_json = dataset.to_dict(orient='split') if isinstance(dataset, pd.DataFrame) else create_tf_serving_json(dataset)
#   response = requests.request(method='POST', headers=headers, url=url, json=data_json)
#   if response.status_code != 200:
#     raise Exception(f'Request failed with status {response.status_code}, {response.text}')
#   return response.json()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# score_model_test = score_model(X_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Initial Deployment

# %% [markdown]
# ## Shared functions

# %%
def generate_model_uri(run_id):
  artifact_path = 'model'
  return "runs:/{run_id}/{artifact_path}".format(run_id=run_id, artifact_path=artifact_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## DS: Select runs to register
#
# First model development, expects to run multiple experiments and multiple runs with different params. We should select the best run to put into registry

# %%
def get_best_run_of_experiment(experiment_ids, filter_string = "", order_by = None):
  
  """Get a pandas DataFrame of runs that fit the search criteria.
    :param experiment_ids: List of experiment IDs.
    :param filter_string: Filter query string, defaults to searching all runs.
    :param order_by: List of columns to order by (e.g., "metrics.rmse"). The ``order_by`` column
                     can contain an optional ``DESC`` or ``ASC`` value. The default is ``ASC``.
                     The default ordering is to sort by ``start_time DESC``, then ``run_id``.
    :return:  ``pandas.DataFrame`` of runs, where each metric,
             parameter, and tag is expanded into its own column named metrics.*, params.*, or
             tags.* respectively. For runs that don't have a particular metric, parameter, or tag,
             the value for the corresponding column is (NumPy) ``Nan``, ``None``, or ``None``
             respectively.

    """
  import mlflow
  
  filter_string = filter_string.strip()
  if ('status' not in filter_string.lower()) and (filter_string != ''):
    filter_string = " and ".join(["status == 'FINISHED'", filter_string])

  
  if order_by is not None:
    if len([el for el in order_by if "start_time" in el]) == 0:
      order_by= order_by + ["start_time DESC"]
  
  pdf = mlflow.search_runs(
    experiment_ids = experiment_ids, 
    filter_string = filter_string, 
    order_by= order_by
  )
  run_id = list(pdf.run_id)[0]
  return run_id

# experiment_ids = list(set([mlflow.get_experiment_by_name(name).experiment_id for name in ["/my-experiment"]]))
experiment_ids = list(set([mlflow.get_experiment_by_name(name).experiment_id for name in [experiment.name]]))
run_id = get_best_run_of_experiment(experiment_ids = experiment_ids, order_by = ["metrics.test_accuracy DESC"])

from mlflow.tracking.client import MlflowClient
client = MlflowClient()


client.set_tag(run_id, KEY_EVALUATION, {"name": "test_accuracy_expectation", "expectation": 0.6})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## DS: Register Demo Model

# %%
model_name = 'iris_decision_tree'

model_uri = generate_model_uri(run_id)
model_details = mlflow.register_model(model_uri=model_uri, name=model_name)


import time
from mlflow.tracking.client import MlflowClient
from mlflow.entities.model_registry.model_version_status import ModelVersionStatus
 
def wait_until_ready(model_name, model_version):
  client = MlflowClient()
  for _ in range(10):
    model_version_details = client.get_model_version(
      name=model_name,
      version=model_version,
    )
    status = ModelVersionStatus.from_string(model_version_details.status)
    print("Model status: %s" % ModelVersionStatus.to_string(status))
    if status == ModelVersionStatus.READY:
      break
    time.sleep(1)
    
    
wait_until_ready(model_details.name, model_details.version)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Registered model &#39;iris_decision_tree&#39; already exists. Creating a new version of this model...
# 2021/07/23 07:57:09 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: iris_decision_tree, version 2
# Created version &#39;2&#39; of model &#39;iris_decision_tree&#39;.
# Model status: READY
# </div>

# %% [markdown]
# ## Transit Demo Model
#
# Model are transited into staging to run additional tests on and compare with production model.
#
# Select one of the registered model to promote to staging

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()
client.transition_model_version_stage(
    name=model_details.name,
    version=model_details.version,
    stage="Staging",
    archive_existing_versions = True
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: &lt;ModelVersion: creation_timestamp=1627027029166, current_stage=&#39;Staging&#39;, description=&#39;&#39;, last_updated_timestamp=1627027036968, name=&#39;iris_decision_tree&#39;, run_id=&#39;b745bf9006eb47bfad37433205883475&#39;, run_link=&#39;&#39;, source=&#39;dbfs:/databricks/mlflow-tracking/2745492199537729/b745bf9006eb47bfad37433205883475/artifacts/model&#39;, status=&#39;READY&#39;, status_message=&#39;&#39;, tags={}, user_id=&#39;7458570827893382&#39;, version=&#39;2&#39;&gt;</div>

# %% [markdown]
# ## Get latest Production/Staging model

# %%
def load_model(run_id):
  from mlflow.tracking.client import MlflowClient
  client = MlflowClient()
  model_uri = generate_model_uri(run_id)
  model = mlflow.pyfunc.load_model(model_uri)
  return model

def get_lastest_model(model_name: str, stage: str):
  """
  Latest version models for requested stage. If no ``stages`` provided, returns the
        latest version for each stage.

  :param model_name: Name of the registered model to update.
  :param stage: Desired stage. 'Staging', 'Production', 'Archived'. Case-insensitive
  :return: A :py:class:`mlflow.entities.model_registry.ModelVersion` object. Return None if no version found under desired stage

  """

  import mlflow
  
  client = mlflow.tracking.MlflowClient() 
  stages = [stage]
  models = client.get_latest_versions(name = model_name, stages=[stage])
  if len(models) >0:
    latest_model = models[0]
  else:
    latest_model = None
    
  return latest_model

stg_model_version = get_lastest_model(model_name = model_name, stage = 'Staging')
prod_model_version = get_lastest_model(model_name = model_name, stage = 'Production')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Compare with production model and transit staging to production if better than production

# %%
import json
stg_model = load_model(stg_model_version.run_id)

X_train, X_test, y_train, y_test = load_iris_data() # notebook by DS to generate new test data
y_pred = stg_model.predict(X_test)

test_accuracy = metrics.accuracy_score(y_test, y_pred)
test_f1_score = metrics.f1_score(y_test, y_pred, average='weighted')
test_metrics = (test_accuracy, test_f1_score)


expectation_metric = client.get_run(stg_model_version.run_id).data.tags[KEY_EVALUATION].replace("'", "\"")
expectation_metric = json.loads(expectation_metric)
expectation_metric_name = expectation_metric['name']
expectation_val = float(expectation_metric['expectation'])

expectation_val
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 0.6</div>

# %%
if (prod_model_version is not None) and (test_accuracy > expectation_val):
  
  prod_model = load_model(prod_model_version.run_id)
  y_pred_prod = prod_model.predict(X_test)
  test_accuracy_prod = metrics.accuracy_score(y_test, y_pred_prod)
  test_f1_score_prod = metrics.f1_score(y_test, y_pred_prod, average='weighted')
  test_metrics_prod = (test_accuracy, test_f1_score)
  
  if (test_f1_score_prod <= test_f1_score):
    client.transition_model_version_stage(
    name=stg_model_version.name,
    version=stg_model_version.version,
    stage="Production",
    archive_existing_versions = True
  )
else:
  client.transition_model_version_stage(
    name=stg_model_version.name,
    version=stg_model_version.version,
    stage="Production",
    archive_existing_versions = True
  )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()
for rm in client.list_registered_models():
  print(f"name={rm.name}")
  [(print(f"run_id={mv.run_id}"), print(f"status={mv.current_stage}"),
         print(f"version={mv.version}"), print(f"creation_timestamp={rm.creation_timestamp}")) for mv in rm.latest_versions]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">name=iris_decision_tree
# run_id=4cf6ffaada2f4ede9f33cddc166ef968
# status=Production
# version=1
# creation_timestamp=1627026659858
# </div>

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()
for mv in client.search_model_versions("name = '{model_name}'".format(model_name = model_name)):
  print(f"run_id={mv.run_id}")
  print(f"status={mv.current_stage}")
  print(f"version={mv.version}")
  print(f"creation_timestamp={rm.creation_timestamp}")
  print()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">run_id=4cf6ffaada2f4ede9f33cddc166ef968
# status=Production
# version=1
# creation_timestamp=1627026659858
#
# </div>

# %%
def delete_archived_models(model_name, keep_latest = False):
  from mlflow.tracking import MlflowClient
  
  client = MlflowClient()
  model_version_infos = client.search_model_versions("name = '{model_name}'".format(model_name = model_name))
  archived_versions = [mv for mv in model_version_infos if mv.current_stage == 'Archived']
  
  if keep_latest:
    latest_av = get_lastest_model(model_name = model_name, stage = 'Archived')
    archived_versions = [av for av in archived_versions if av.version != latest_av.version]
  
  for av in archived_versions:
    client.delete_model_version(name=model_name, version=av.version)

delete_archived_models(model_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()
for mv in client.search_model_versions("name = '{model_name}'".format(model_name = model_name)):
  print(f"run_id={mv.run_id}")
  print(f"status={mv.current_stage}")
  print(f"version={mv.version}")
  print(f"creation_timestamp={rm.creation_timestamp}")
  print()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">run_id=3d24656d8ccc462bbc8d727fbf5af482
# status=Production
# version=5
# creation_timestamp=1626955914600
#
# </div>

# %% [markdown]
# https://mlflow.org/docs/latest/python_api/mlflow.html#mlflow.search_runs

# %% [markdown]
# https://docs.databricks.com/data/data-sources/mlflow-experiment.html#mlflow-exp-datasource
